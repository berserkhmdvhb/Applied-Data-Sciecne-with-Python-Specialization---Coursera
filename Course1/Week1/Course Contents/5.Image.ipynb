# %%
from PIL import Image
from IPython.display import display

# %%
im = Image.open('NGE.jpg')

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x685 at 0x7F8A5A436C50>

# %%
arr = np.array(im)

# %%
arr
# Out:
# array([[[167, 177, 187],
#         [174, 184, 194],
#         [172, 189, 197],
#         ...,
#         [101,  33,  34],
#         [103,  34,  37],
#         [102,  33,  36]],
#
#        [[157, 175, 187],
#         [162, 184, 195],
#         [161, 185, 195],
#         ...,
#         [105,  35,  37],
#         [102,  33,  36],
#         [102,  33,  36]],
#
#        [[125, 170, 189],
#         [128, 175, 193],
#         [130, 179, 194],
#         ...,
#         [104,  32,  35],
#         [102,  31,  35],
#         [100,  31,  34]],
#
#        ...,
#
#        [[ 24,  35,  55],
#         [ 29,  41,  65],
#         [ 28,  44,  69],
#         ...,
#         [119, 168, 182],
#         [117, 165, 179],
#         [117, 165, 179]],
#
#        [[ 25,  37,  59],
#         [ 26,  41,  64],
#         [ 29,  43,  69],
#         ...,
#         [120, 169, 183],
#         [116, 165, 179],
#         [115, 164, 178]],
#
#        [[ 24,  39,  60],
#         [ 25,  39,  65],
#         [ 30,  41,  69],
#         ...,
#         [117, 169, 182],
#         [116, 168, 181],
#         [112, 164, 177]]], dtype=uint8)

# %%
mask = np.full(array.shape,255)
mask = mask.astype(np.uint8)

pale = np.full(array.shape,0)
pale = pale.astype(np.uint8)

# %%
array.shape
# Out:
# (685, 500, 3)

# %%
modified_array = mask - array
modified_array = modified_array.astype(np.uint8)

# %%
modified_array.dtype
# Out:
# dtype('uint8')

# %%
display(Image.fromarray(modified_array))
# Out:
# <PIL.Image.Image image mode=RGB size=500x685 at 0x7F8A4DB5FBE0>
